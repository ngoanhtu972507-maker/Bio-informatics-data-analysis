# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.13/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.13/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.3.3-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.13/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.7.22)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.13/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (26.1.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-26.2.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.11.7)
# Collecting url-normalize>=2.0 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-3.0.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.16.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.0 MB/s eta 0:00:00
# Downloading requests_cache-1.3.3-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 kB 6.1 MB/s eta 0:00:00
# Downloading cattrs-26.2.0-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 6.2 MB/s eta 0:00:00
# Downloading url_normalize-3.0.0-py3-none-any.whl (16 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-26.2.0 chembl_webresource_client-0.10.9 requests-cache-1.3.3 url-normalize-3.0.0

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client
# Out:
# /usr/local/lib/python3.13/dist-packages/chembl_webresource_client/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __version__ = __import__('pkg_resources').get_distribution('chembl_webresource_client').version

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references                   organism  \
# 0                []    Drosophila melanogaster
# 1                []               Homo sapiens
# 2                []        Torpedo californica
# 3                []               Mus musculus
# 4                []          Rattus norvegicus
# 5                []   Electrophorus electricus
# 6                []                 Bos taurus
# 7                []          Anopheles gambiae
# 8                []             Bemisia tabaci
# 9                []  Leptinotarsa decemlineata
# 10               []     Nephotettix cincticeps
# 11               []              Gallus gallus
# 12               []                Danio rerio
# 13               []              Aedes aegypti
# 14               []               Homo sapiens
# 15               []            Musca domestica
# 16               []        Plutella xylostella
# 17               []            Musca domestica
# 18               []  Pediculus humanus capitis
# 19               []          Spodoptera litura
# 20               []      Laodelphax striatella
# 21               []        Schizaphis graminum
# 22               []               Homo sapiens
# 23               []          Rattus norvegicus
# 24               []     Caenorhabditis elegans
# 25               []             Equus caballus
# 26               []             Equus caballus
# 27               []     Canis lupus familiaris
# 28               []               Mus musculus
# 29               []          Rattus norvegicus
# 30               []               Homo sapiens
#
#                                             pref_name  score  \
# 0                                Acetylcholinesterase   18.0
# 1                                Acetylcholinesterase   16.0
# 2                                Acetylcholinesterase   16.0
# 3                                Acetylcholinesterase   16.0
# 4                                Acetylcholinesterase   16.0
# 5                                Acetylcholinesterase   16.0
# 6                                Acetylcholinesterase   16.0
# 7                                Acetylcholinesterase   16.0
# 8                                               AChE2   16.0
# 9                                Acetylcholinesterase   16.0
# 10               Ace-orthologous acetylcholinesterase   16.0
# 11                               Acetylcholinesterase   16.0
# 12                               Acetylcholinesterase   16.0
# 13                               Acetylcholinesterase   16.0
# 14                                       Protein CutA   16.0
# 15                               Acetylcholinesterase   15.0
# 16                               Acetylcholinesterase   15.0
# 17                               Acetylcholinesterase   15.0
# 18                               Acetylcholinesterase   15.0
# 19                               Acetylcholinesterase   15.0
# 20                               Acetylcholinesterase   15.0
# 21                               Acetylcholinesterase   15.0
# 22                       Cholinesterases; ACHE & BCHE   14.0
# 23  Acetylcholinesterase and butyrylcholinesterase...   14.0
# 24                             Acetylcholinesterase 1   14.0
# 25                              Butyrylcholinesterase   11.0
# 26                                     Cholinesterase   11.0
# 27                                     Cholinesterase   11.0
# 28                                     Cholinesterase   10.0
# 29                              Butyrylcholinesterase   10.0
# 30                                     Cholinesterase    5.0
#
#     species_group_flag target_chembl_id  \
# 0                False    CHEMBL2242744
# 1                False        CHEMBL220
# 2                False       CHEMBL4780
# 3                False       CHEMBL3198
# 4                False       CHEMBL3199
# 5                False       CHEMBL4078
# 6                False       CHEMBL4768
# 7                False    CHEMBL2046266
# 8                False    CHEMBL2366409
# 9                False    CHEMBL2366490
# 10               False    CHEMBL2366514
# 11               False    CHEMBL3227914
# 12               False    CHEMBL3308995
# 13               False    CHEMBL4295607
# 14               False    CHEMBL6067022
# 15               False       CHEMBL5752
# 16               False    CHEMBL2242729
# 17               False    CHEMBL2242743
# 18               False    CHEMBL2362988
# 19               False    CHEMBL2366422
# 20               False    CHEMBL2366446
# 21               False    CHEMBL2366511
# 22               False    CHEMBL2095233
# 23               False    CHEMBL2111475
# 24               False    CHEMBL3341583
# 25               False       CHEMBL5077
# 26               False       CHEMBL5763
# 27               False    CHEMBL4630814
# 28               False       CHEMBL2528
# 29               False       CHEMBL3403
# 30               False       CHEMBL1914
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 2   [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'P37136', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'O42275', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'P23795', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'Q869C3', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'B3SST5', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'Q27677', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'Q9NJH6', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'P36196', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'Q9DDE3', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'Q6A2E2', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'O60888', 'component_descriptio...     SINGLE PROTEIN
# 15  [{'accession': 'Q95P20', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'Q8MZM0', 'component_descriptio...     SINGLE PROTEIN
# 17  [{'accession': 'Q7YWJ9', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'A2PZ98', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'C5IU80', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'K4JQ36', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'Q9BMJ1', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 23  [{'accession': 'P37136', 'component_descriptio...  SELECTIVITY GROUP
# 24  [{'accession': 'P38433', 'component_descriptio...     SINGLE PROTEIN
# 25  [{'accession': 'Q9N1N9', 'component_descriptio...     SINGLE PROTEIN
# 26  [{'accession': 'P81908', 'component_descriptio...     SINGLE PROTEIN
# 27  [{'accession': 'P32750', 'component_descriptio...     SINGLE PROTEIN
# 28  [{'accession': 'Q03311', 'component_descriptio...     SINGLE PROTEIN
# 29  [{'accession': 'Q9JKC1', 'component_descriptio...     SINGLE PROTEIN
# 30  [{'accession': 'P06276', 'component_descriptio...     SINGLE PROTEIN
#
#     tax_id
# 0     7227
# 1     9606
# 2     7787
# 3    10090
# 4    10116
# 5     8005
# 6     9913
# 7     7165
# 8     7038
# 9     7539
# 10   94400
# 11    9031
# 12    7955
# 13    7159
# 14    9606
# 15    7370
# 16   51655
# 17    7370
# 18  121226
# 19   69820
# 20  195883
# 21   13262
# 22    9606
# 23   10116
# 24    6239
# 25    9796
# 26    9796
# 27    9615
# 28   10090
# 29   10116
# 30    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (second entry)**

# %% [markdown]
# We will assign the second entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL220'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                              action_type activity_comment  \
# 0                                                   None             None
# 1                                                   None             None
# 2                                                   None             None
# 3                                                   None             None
# 4                                                   None             None
# ...                                                  ...              ...
# 10074  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10075  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10076  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10077  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10078  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#        activity_id activity_properties assay_chembl_id  \
# 0            33969                  []    CHEMBL643384
# 1            37563                  []    CHEMBL643384
# 2            37565                  []    CHEMBL643384
# 3            38902                  []    CHEMBL643384
# 4            41170                  []    CHEMBL643384
# ...            ...                 ...             ...
# 10074     29307984                  []   CHEMBL6183009
# 10075     29307985                  []   CHEMBL6183009
# 10076     29309041                  []   CHEMBL6183244
# 10077     29309042                  []   CHEMBL6183244
# 10078     29309043                  []   CHEMBL6183244
#
#                                        assay_description assay_type  \
# 0      Inhibitory concentration against acetylcholine...          B
# 1      Inhibitory concentration against acetylcholine...          B
# 2      Inhibitory concentration against acetylcholine...          B
# 3      Inhibitory concentration against acetylcholine...          B
# 4      Inhibitory concentration against acetylcholine...          B
# ...                                                  ...        ...
# 10074                Inhibition of AChE (unknown origin)          B
# 10075                Inhibition of AChE (unknown origin)          B
# 10076                Inhibition of AChE (unknown origin)          B
# 10077                Inhibition of AChE (unknown origin)          B
# 10078                Inhibition of AChE (unknown origin)          B
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                        None                   None  BAO_0000190  ...
# 1                        None                   None  BAO_0000190  ...
# 2                        None                   None  BAO_0000190  ...
# 3                        None                   None  BAO_0000190  ...
# 4                        None                   None  BAO_0000190  ...
# ...                       ...                    ...          ...  ...
# 10074                    None                   None  BAO_0000190  ...
# 10075                    None                   None  BAO_0000190  ...
# 10076                    None                   None  BAO_0000190  ...
# 10077                    None                   None  BAO_0000190  ...
# 10078                    None                   None  BAO_0000190  ...
#
#       target_organism      target_pref_name target_tax_id text_value  toid  \
# 0        Homo sapiens  Acetylcholinesterase          9606       None  None
# 1        Homo sapiens  Acetylcholinesterase          9606       None  None
# 2        Homo sapiens  Acetylcholinesterase          9606       None  None
# 3        Homo sapiens  Acetylcholinesterase          9606       None  None
# 4        Homo sapiens  Acetylcholinesterase          9606       None  None
# ...               ...                   ...           ...        ...   ...
# 10074    Homo sapiens  Acetylcholinesterase          9606       None  None
# 10075    Homo sapiens  Acetylcholinesterase          9606       None  None
# 10076    Homo sapiens  Acetylcholinesterase          9606       None  None
# 10077    Homo sapiens  Acetylcholinesterase          9606       None  None
# 10078    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#        type units    uo_units upper_value  value
# 0      IC50    uM  UO_0000065        None   0.75
# 1      IC50    uM  UO_0000065        None    0.1
# 2      IC50    uM  UO_0000065        None   50.0
# 3      IC50    uM  UO_0000065        None    0.3
# 4      IC50    uM  UO_0000065        None    0.8
# ...     ...   ...         ...         ...    ...
# 10074  IC50    uM  UO_0000065        None    0.4
# 10075  IC50    uM  UO_0000065        None   2.16
# 10076  IC50    nM  UO_0000065        None   11.1
# 10077  IC50    uM  UO_0000065        None  0.052
# 10078  IC50    nM  UO_0000065        None   2.61
#
# [10079 rows x 47 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /tmp/ipykernel_2093/3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                              action_type activity_comment  \
# 0                                                   None             None
# 1                                                   None             None
# 2                                                   None             None
# 3                                                   None             None
# 4                                                   None             None
# ...                                                  ...              ...
# 10074  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10075  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10076  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10077  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10078  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#        activity_id activity_properties assay_chembl_id  \
# 0            33969                  []    CHEMBL643384
# 1            37563                  []    CHEMBL643384
# 2            37565                  []    CHEMBL643384
# 3            38902                  []    CHEMBL643384
# 4            41170                  []    CHEMBL643384
# ...            ...                 ...             ...
# 10074     29307984                  []   CHEMBL6183009
# 10075     29307985                  []   CHEMBL6183009
# 10076     29309041                  []   CHEMBL6183244
# 10077     29309042                  []   CHEMBL6183244
# 10078     29309043                  []   CHEMBL6183244
#
#                                        assay_description assay_type  \
# 0      Inhibitory concentration against acetylcholine...          B
# 1      Inhibitory concentration against acetylcholine...          B
# 2      Inhibitory concentration against acetylcholine...          B
# 3      Inhibitory concentration against acetylcholine...          B
# 4      Inhibitory concentration against acetylcholine...          B
# ...                                                  ...        ...
# 10074                Inhibition of AChE (unknown origin)          B
# 10075                Inhibition of AChE (unknown origin)          B
# 10076                Inhibition of AChE (unknown origin)          B
# 10077                Inhibition of AChE (unknown origin)          B
# 10078                Inhibition of AChE (unknown origin)          B
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                        None                   None  BAO_0000190  ...
# 1                        None                   None  BAO_0000190  ...
# 2                        None                   None  BAO_0000190  ...
# 3                        None                   None  BAO_0000190  ...
# 4                        None                   None  BAO_0000190  ...
# ...                       ...                    ...          ...  ...
# 10074                    None                   None  BAO_0000190  ...
# 10075                    None                   None  BAO_0000190  ...
# 10076                    None                   None  BAO_0000190  ...
# 10077                    None                   None  BAO_0000190  ...
# 10078                    None                   None  BAO_0000190  ...
#
#       target_organism      target_pref_name target_tax_id text_value  toid  \
# 0        Homo sapiens  Acetylcholinesterase          9606       None  None
# 1        Homo sapiens  Acetylcholinesterase          9606       None  None
# 2        Homo sapiens  Acetylcholinesterase          9606       None  None
# 3        Homo sapiens  Acetylcholinesterase          9606       None  None
# 4        Homo sapiens  Acetylcholinesterase          9606       None  None
# ...               ...                   ...           ...        ...   ...
# 10074    Homo sapiens  Acetylcholinesterase          9606       None  None
# 10075    Homo sapiens  Acetylcholinesterase          9606       None  None
# 10076    Homo sapiens  Acetylcholinesterase          9606       None  None
# 10077    Homo sapiens  Acetylcholinesterase          9606       None  None
# 10078    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#        type units    uo_units upper_value  value
# 0      IC50    uM  UO_0000065        None   0.75
# 1      IC50    uM  UO_0000065        None    0.1
# 2      IC50    uM  UO_0000065        None   50.0
# 3      IC50    uM  UO_0000065        None    0.3
# 4      IC50    uM  UO_0000065        None    0.8
# ...     ...   ...         ...         ...    ...
# 10074  IC50    uM  UO_0000065        None    0.4
# 10075  IC50    uM  UO_0000065        None   2.16
# 10076  IC50    nM  UO_0000065        None   11.1
# 10077  IC50    uM  UO_0000065        None  0.052
# 10078  IC50    nM  UO_0000065        None   2.61
#
# [8791 rows x 47 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 7175

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                              action_type activity_comment  \
# 0                                                   None             None
# 1                                                   None             None
# 2                                                   None             None
# 3                                                   None             None
# 4                                                   None             None
# ...                                                  ...              ...
# 10073  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10074  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10076  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10077  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 10078  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#        activity_id activity_properties assay_chembl_id  \
# 0            33969                  []    CHEMBL643384
# 1            37563                  []    CHEMBL643384
# 2            37565                  []    CHEMBL643384
# 3            38902                  []    CHEMBL643384
# 4            41170                  []    CHEMBL643384
# ...            ...                 ...             ...
# 10073     29307981                  []   CHEMBL6183007
# 10074     29307984                  []   CHEMBL6183009
# 10076     29309041                  []   CHEMBL6183244
# 10077     29309042                  []   CHEMBL6183244
# 10078     29309043                  []   CHEMBL6183244
#
#                                        assay_description assay_type  \
# 0      Inhibitory concentration against acetylcholine...          B
# 1      Inhibitory concentration against acetylcholine...          B
# 2      Inhibitory concentration against acetylcholine...          B
# 3      Inhibitory concentration against acetylcholine...          B
# 4      Inhibitory concentration against acetylcholine...          B
# ...                                                  ...        ...
# 10073  Inhibition of AChE (unknown origin) using acet...          B
# 10074                Inhibition of AChE (unknown origin)          B
# 10076                Inhibition of AChE (unknown origin)          B
# 10077                Inhibition of AChE (unknown origin)          B
# 10078                Inhibition of AChE (unknown origin)          B
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                        None                   None  BAO_0000190  ...
# 1                        None                   None  BAO_0000190  ...
# 2                        None                   None  BAO_0000190  ...
# 3                        None                   None  BAO_0000190  ...
# 4                        None                   None  BAO_0000190  ...
# ...                       ...                    ...          ...  ...
# 10073                    None                   None  BAO_0000190  ...
# 10074                    None                   None  BAO_0000190  ...
# 10076                    None                   None  BAO_0000190  ...
# 10077                    None                   None  BAO_0000190  ...
# 10078                    None                   None  BAO_0000190  ...
#
#       target_organism      target_pref_name target_tax_id text_value  toid  \
# 0        Homo sapiens  Acetylcholinesterase          9606       None  None
# 1        Homo sapiens  Acetylcholinesterase          9606       None  None
# 2        Homo sapiens  Acetylcholinesterase          9606       None  None
# 3        Homo sapiens  Acetylcholinesterase          9606       None  None
# 4        Homo sapiens  Acetylcholinesterase          9606       None  None
# ...               ...                   ...           ...        ...   ...
# 10073    Homo sapiens  Acetylcholinesterase          9606       None  None
# 10074    Homo sapiens  Acetylcholinesterase          9606       None  None
# 10076    Homo sapiens  Acetylcholinesterase          9606       None  None
# 10077    Homo sapiens  Acetylcholinesterase          9606       None  None
# 10078    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#        type units    uo_units upper_value  value
# 0      IC50    uM  UO_0000065        None   0.75
# 1      IC50    uM  UO_0000065        None    0.1
# 2      IC50    uM  UO_0000065        None   50.0
# 3      IC50    uM  UO_0000065        None    0.3
# 4      IC50    uM  UO_0000065        None    0.8
# ...     ...   ...         ...         ...    ...
# 10073  IC50    nM  UO_0000065        None   0.48
# 10074  IC50    uM  UO_0000065        None    0.4
# 10076  IC50    nM  UO_0000065        None   11.1
# 10077  IC50    uM  UO_0000065        None  0.052
# 10078  IC50    nM  UO_0000065        None   2.61
#
# [7175 rows x 47 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1           CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2           CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3           CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4           CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                  ...                                                ...
# 10073      CHEMBL6190210  FC(F)(F)c1cccc(-c2cc(-c3cccs3)n(-c3ccc(Br)cc3)...
# 10074      CHEMBL6192902         O=C(NNC(=S)Nc1ccccc1[N+](=O)[O-])c1sccc1Cl
# 10076      CHEMBL6191782  Cc1cc(=O)[nH]c2c1C(=O)C(NCNc1c3c(nc4ccccc14)CC...
# 10077      CHEMBL6190113    O=C(NCCCNc1c2c(nc3ccccc13)CCC2)c1cnc(Cl)c(Cl)c1
# 10078      CHEMBL6188323  COc1cc2c(cc1OC)CC(CN1CCN(CCCNc3c4c(nc5cc(Cl)cc...
#
#       standard_value
# 0              750.0
# 1              100.0
# 2            50000.0
# 3              300.0
# 4              800.0
# ...              ...
# 10073           0.48
# 10074          400.0
# 10076           11.1
# 10077           52.0
# 10078           2.61
#
# [7175 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 7170      CHEMBL6190210  FC(F)(F)c1cccc(-c2cc(-c3cccs3)n(-c3ccc(Br)cc3)...
# 7171      CHEMBL6192902         O=C(NNC(=S)Nc1ccccc1[N+](=O)[O-])c1sccc1Cl
# 7172      CHEMBL6191782  Cc1cc(=O)[nH]c2c1C(=O)C(NCNc1c3c(nc4ccccc14)CC...
# 7173      CHEMBL6190113    O=C(NCCCNc1c2c(nc3ccccc13)CCC2)c1cnc(Cl)c(Cl)c1
# 7174      CHEMBL6188323  COc1cc2c(cc1OC)CC(CN1CCN(CCCNc3c4c(nc5cc(Cl)cc...
#
#       standard_value     class
# 0             750.00    active
# 1             100.00    active
# 2           50000.00  inactive
# 3             300.00    active
# 4             800.00    active
# ...              ...       ...
# 7170            0.48    active
# 7171          400.00    active
# 7172           11.10    active
# 7173           52.00    active
# 7174            2.61    active
#
# [7175 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 92%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 80%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 7788
# -rw-r--r-- 1 root root 6120086 Sep 10 14:17 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  527573 Sep 10 14:20 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  593411 Sep 10 14:20 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  724212 Sep 10 14:20 acetylcholinesterase.zip
# drwxr-xr-x 1 root root    4096 Sep  4 13:25 sample_data

# %% [markdown]
# ---
